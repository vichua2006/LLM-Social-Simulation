# %%
import pandas as pd
import numpy as np

# For example, to load from a CSV file
filepath = '/Users/l/Downloads/Supplementary Material 2/CSV/BaseLine/Experiment-0-1.csv'
df = pd.read_csv(filepath)
df = df[df.iloc[:, 0]!='Average'].iloc[:, 1:].drop(columns=["Day run", "Convergence No More than 50 Rounds (Yes/No)", "Trade Count Before", "Trade Count After", 
                                                            "Trade Accepted Count Before", "Trade Accepted Count After","Rob Count Before", "Rob Count After", "Rob Rebelled Count Before", "Rob Rebelled Count After", "Farm Count Before", "Farm Count After"])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 7
#       5 filepath = '/Users/l/Downloads/Supplementary Material 2/CSV/BaseLine/Experiment-0-1.csv'
#       6 df = pd.read_csv(filepath)
# ----> 7 df = df[df.iloc[:, 0]!='Average'].iloc[:, 1:].drop(columns=["Day run", "Convergence No More than 50 Rounds (Yes/No)", "Trade Count Before", "Trade Count After",
#       8                                                             "Trade Accepted Count Before", "Trade Accepted Count After","Rob Count Before", "Rob Count After", "Rob Rebelled Count Before", "Rob Rebelled Count After", "Farm Count Before", "Farm Count After"])
#       9 df
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
# ...

# %%
df_filter = df.loc[:, df.nunique() > 1]

# %%
correlation_matrix = df_filter.corr()
correlation_matrix
# Out:
#                             Aggressiveness (Mean)  Aggressiveness (Var)  \
# Aggressiveness (Mean)                1.000000e+00          5.204972e-19
# Aggressiveness (Var)                 5.204972e-19          1.000000e+00
# Covetousness (Mean)                  5.242350e-19         -5.414952e-02
# Covetousness (Var)                   7.765736e-19         -8.021420e-02
# Intelligence                        -4.700329e-19          4.855085e-02
# Strength (Var)                      -1.141605e-17         -5.907444e-02
# Population (people)                  1.710338e-17         -4.807882e-02
# Prompt                               6.692658e-19         -6.913011e-02
# Trade Rate Before                   -1.896096e-01         -1.549209e-01
# Trade Rate After                    -1.207186e-03         -1.020618e-01
# Trade Accepted Rate Before          -1.086659e-02         -4.591180e-02
# Trade Accepted Rate After            9.896241e-02         -1.140515e-01
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the figure size
plt.figure(figsize=(20, 15))

# Using a heatmap to visualize the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

plt.title("Correlation Matrix")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.savefig(filepath+ " correlation matrix.png")
plt.show()
